# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json

# %%
def convert_to_json_of_arrays(array_of_jsons):
    json_of_arrays = {}

    # Iterate through each JSON in the array
    for json_obj in array_of_jsons:
        for key, value in json_obj.items():
            # Check if the key exists in the new JSON, if not, create an array
            if key not in json_of_arrays:
                json_of_arrays[key] = []

            # Append the value to the corresponding array
            json_of_arrays[key].append(value)

    return json_of_arrays

# %%
compas = pd.read_csv('compas_result.csv')

# %%
compas.replace({'ftl_mlp_initializer': 'Fair Transition Loss', 'adversarial_debiasing_initializer': 'Adversarial Debiasing', 'gerry_fair_classifier_initializer': 'Gerry Fair Classifier', 'prejudice_remover_initializer': 'Prejudice Remover', 'simple_mlp_initializer': 'Standard MLP (baseline)'}, inplace=True)

# %%
cols = ['method', 'fitness_rule', 'fitness', 'ACC', 'MCC', 'f1_score', 'avg_odds_diff', 'stat_par_diff', 'eq_opp_diff']

# %%
compas[cols].sort_values(by=['fitness_rule','fitness'], ascending=False)
# Out:
#                      method     fitness_rule   fitness       ACC       MCC  \
# 2     Adversarial Debiasing       mcc_parity  0.322387  0.671799  0.337376
# 1      Fair Transition Loss       mcc_parity  0.273175  0.637763  0.284738
# 4     Gerry Fair Classifier       mcc_parity  0.138711  0.616694  0.240203
# 3         Prejudice Remover       mcc_parity -0.397930  0.337925 -0.323429
# 0   Standard MLP (baseline)       mcc_parity -0.402529  0.364668 -0.255084
# 7     Adversarial Debiasing  mcc_opportunity  0.231140  0.664506  0.318068
# 9     Gerry Fair Classifier  mcc_opportunity  0.173886  0.619125  0.216441
# 6      Fair Transition Loss  mcc_opportunity  0.104233  0.646677  0.290247
# 8         Prejudice Remover  mcc_opportunity -0.335880  0.331442 -0.320137
# 5   Standard MLP (baseline)  mcc_opportunity -0.466437  0.358995 -0.263183
# 22    Adversarial Debiasing         mcc_odds  0.286168  0.678282  0.351880
# 24    Gerry Fair Classifier         mcc_odds  0.255934  0.636953  0.286634
# 21     Fair Transition Loss         mcc_odds  0.253381  0.650729  0.317086
# 23        Prejudice Remover         mcc_odds -0.345477  0.382496 -0.215258
# 20  Standard MLP (baseline)         mcc_odds -0.579086  0.334684 -0.308483
# 11     Fair Transition Loss       acc_parity  0.593142  0.606969  0.193672
# 12    Adversarial Debiasing       acc_parity  0.554321  0.664506  0.322036
# 14    Gerry Fair Classifier       acc_parity  0.408634  0.417342 -0.092488
# 13        Prejudice Remover       acc_parity  0.343839  0.363857 -0.257778
# 10  Standard MLP (baseline)       acc_parity  0.133180  0.338736 -0.305265
# 17    Adversarial Debiasing  acc_opportunity  0.584689  0.656402  0.304880
# 16     Fair Transition Loss  acc_opportunity  0.578619  0.603728  0.203451
# 19    Gerry Fair Classifier  acc_opportunity  0.350475  0.604538  0.240531
# 18        Prejudice Remover  acc_opportunity  0.326839  0.354133 -0.271986
# 15  Standard MLP (baseline)  acc_opportunity  0.261604  0.366288 -0.255574
# 26     Fair Transition Loss         acc_odds  0.630205  0.653160  0.295390
# 27    Adversarial Debiasing         acc_odds  0.550824  0.681524  0.348598
# 29    Gerry Fair Classifier         acc_odds  0.502334  0.658023  0.307021
# 28        Prejudice Remover         acc_odds  0.276268  0.367099 -0.256942
# 25  Standard MLP (baseline)         acc_odds  0.103883  0.356564 -0.283446
#
#     f1_score  avg_odds_diff  stat_par_diff  eq_opp_diff
# 2   0.701107       0.029781       0.014989     0.031048
# 1   0.628429       0.015651       0.011562     0.023973
# 4   0.721273       0.093147       0.101493     0.064522
# 3   0.255242       0.101173       0.074500     0.037162
# 0   0.355263       0.128451       0.147445     0.074805
# 7   0.704286       0.110528       0.124747     0.086928
# 9   0.728950       0.076662       0.083893     0.042556
# 6   0.669697       0.190594       0.148785     0.186014
# 8   0.286949       0.077070       0.101491     0.015742
# 5   0.325661       0.227316       0.247902     0.203254
# 22  0.703510       0.065712       0.102318     0.065909
# 24  0.718239       0.030700       0.047896     0.009392
# 21  0.639933       0.063705       0.089442     0.014384
# 23  0.313514       0.130219       0.040958     0.084179
# 20  0.292851       0.270602       0.274644     0.184417
# 11  0.723961       0.021160       0.013828     0.035802
# 12  0.701729       0.088168       0.110184     0.027549
# 14  0.042610       0.010099       0.008708     0.019189
# 13  0.275162       0.107346       0.020019     0.095059
# 10  0.300172       0.184278       0.205556     0.147595
# 17  0.695839       0.077690       0.114768     0.071713
# 16  0.633708       0.033155       0.049407     0.025109
# 19  0.574171       0.225461       0.247596     0.254063
# 18  0.281335       0.079069       0.062311     0.027294
# 15  0.323529       0.128204       0.150089     0.104684
# 26  0.711590       0.022955       0.004349     0.042649
# 27  0.724983       0.130699       0.162808     0.082944
# 29  0.702817       0.155689       0.169826     0.036423
# 28  0.313105       0.090830       0.100672     0.006328
# 25  0.360709       0.252681       0.252742     0.197986

# %%
fitness_rules = compas['fitness_rule'].unique().tolist()
fitness_rules
# Out:
# ['mcc_parity',
#  'mcc_opportunity',
#  'acc_parity',
#  'acc_opportunity',
#  'mcc_odds',
#  'acc_odds']

# %%
fitness_rules_target_metrics = {
    'mcc_parity': {'performance': 'MCC', 'fairness': 'stat_par_diff'},
    'mcc_opportunity': {'performance': 'MCC', 'fairness': 'eq_opp_diff'},
    'mcc_odds': {'performance': 'MCC', 'fairness': 'avg_odds_diff'},
    'acc_parity': {'performance': 'ACC', 'fairness': 'stat_par_diff'},
    'acc_opportunity': {'performance': 'ACC', 'fairness': 'eq_opp_diff'},
    'acc_odds': {'performance': 'ACC', 'fairness': 'avg_odds_diff'}
}

# %%
for fitness_rule, metrics in fitness_rules_target_metrics.items():
    compas[compas['fitness_rule'] == fitness_rule][['method', 'fitness', metrics['performance'], metrics['fairness']]].sort_values(by=['fitness'], ascending=False)

# %%
compas[compas['fitness_rule'] == 'mcc_parity'][['method', 'fitness', 'MCC', 'stat_par_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                     method   fitness       MCC  stat_par_diff
# 2    Adversarial Debiasing  0.322387  0.337376       0.014989
# 1     Fair Transition Loss  0.273175  0.284738       0.011562
# 4    Gerry Fair Classifier  0.138711  0.240203       0.101493
# 3        Prejudice Remover -0.397930 -0.323429       0.074500
# 0  Standard MLP (baseline) -0.402529 -0.255084       0.147445

# %%
compas[compas['fitness_rule'] == 'mcc_opportunity'][['method', 'fitness', 'MCC', 'eq_opp_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                     method   fitness       MCC  eq_opp_diff
# 7    Adversarial Debiasing  0.231140  0.318068     0.086928
# 9    Gerry Fair Classifier  0.173886  0.216441     0.042556
# 6     Fair Transition Loss  0.104233  0.290247     0.186014
# 8        Prejudice Remover -0.335880 -0.320137     0.015742
# 5  Standard MLP (baseline) -0.466437 -0.263183     0.203254

# %%
compas[compas['fitness_rule'] == 'acc_odds'][['method', 'fitness', 'ACC', 'avg_odds_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                      method   fitness       ACC  avg_odds_diff
# 26     Fair Transition Loss  0.630205  0.653160       0.022955
# 27    Adversarial Debiasing  0.550824  0.681524       0.130699
# 29    Gerry Fair Classifier  0.502334  0.658023       0.155689
# 28        Prejudice Remover  0.276268  0.367099       0.090830
# 25  Standard MLP (baseline)  0.103883  0.356564       0.252681

# %%
compas[compas['fitness_rule'] == 'acc_parity'][['method', 'fitness', 'ACC', 'stat_par_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                      method   fitness       ACC  stat_par_diff
# 11     Fair Transition Loss  0.593142  0.606969       0.013828
# 12    Adversarial Debiasing  0.554321  0.664506       0.110184
# 14    Gerry Fair Classifier  0.408634  0.417342       0.008708
# 13        Prejudice Remover  0.343839  0.363857       0.020019
# 10  Standard MLP (baseline)  0.133180  0.338736       0.205556

# %%
compas[compas['fitness_rule'] == 'acc_opportunity'][['method', 'fitness', 'ACC', 'eq_opp_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                      method   fitness       ACC  eq_opp_diff
# 17    Adversarial Debiasing  0.584689  0.656402     0.071713
# 16     Fair Transition Loss  0.578619  0.603728     0.025109
# 19    Gerry Fair Classifier  0.350475  0.604538     0.254063
# 18        Prejudice Remover  0.326839  0.354133     0.027294
# 15  Standard MLP (baseline)  0.261604  0.366288     0.104684

# %%
resume = pd.pivot_table(compas, values='fitness', index='method', columns='fitness_rule')
resume
# Out:
# fitness_rule             acc_odds  acc_opportunity  acc_parity  mcc_odds  \
# method
# Adversarial Debiasing    0.550824         0.584689    0.554321  0.286168
# Fair Transition Loss     0.630205         0.578619    0.593142  0.253381
# Gerry Fair Classifier    0.502334         0.350475    0.408634  0.255934
# Prejudice Remover        0.276268         0.326839    0.343839 -0.345477
# Standard MLP (baseline)  0.103883         0.261604    0.133180 -0.579086
#
# fitness_rule             mcc_opportunity  mcc_parity
# method
# Adversarial Debiasing           0.231140    0.322387
# Fair Transition Loss            0.104233    0.273175
# Gerry Fair Classifier           0.173886    0.138711
# Prejudice Remover              -0.335880   -0.397930
# Standard MLP (baseline)        -0.466437   -0.402529

# %%
for fitness_rule in fitness_rules:
    tf_history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
    solution = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['solution'].iloc[0]
    tf_history = json.loads(tf_history.iloc[0].replace('\'', '\"'))
    fig, ax = plt.subplots(figsize=(4, 3), dpi = 150)
    sns.lineplot(tf_history, ax=ax).set(title=fitness_rule)
# Out:
# /tmp/ipykernel_30571/1019958944.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tf_history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
# /tmp/ipykernel_30571/1019958944.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   solution = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['solution'].iloc[0]
# /tmp/ipykernel_30571/1019958944.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tf_history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
# /tmp/ipykernel_30571/1019958944.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   solution = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['solution'].iloc[0]
# /tmp/ipykernel_30571/1019958944.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tf_history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
# /tmp/ipykernel_30571/1019958944.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   solution = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['solution'].iloc[0]
# /tmp/ipykernel_30571/1019958944.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tf_history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
# /tmp/ipykernel_30571/1019958944.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   solution = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['solution'].iloc[0]
# /tmp/ipykernel_30571/1019958944.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tf_history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
# /tmp/ipykernel_30571/1019958944.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   solution = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['solution'].iloc[0]
# /tmp/ipykernel_30571/1019958944.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tf_history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
# /tmp/ipykernel_30571/1019958944.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   solution = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['solution'].iloc[0]

# %%
for fitness_rule, metrics in fitness_rules_target_metrics.items():
    compas[compas['fitness_rule'] == fitness_rule][['method', 'fitness', metrics['performance'], metrics['fairness']]].sort_values(by=['fitness'], ascending=False)

    history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['tune_results_history']\
                .iloc[0].replace('\'','\"').replace('inf','0')
    history = json.loads(history)
    fig, ax = plt.subplots(figsize=(4, 3), dpi = 150)
    sns.scatterplot(convert_to_json_of_arrays(history), x=fitness_rules_target_metrics[fitness_rule]['performance'],
                    y=fitness_rules_target_metrics[fitness_rule]['fairness'], hue='fitness')
# Out:
# /tmp/ipykernel_30571/949018458.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['tune_results_history']\
# /tmp/ipykernel_30571/949018458.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['tune_results_history']\
# /tmp/ipykernel_30571/949018458.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['tune_results_history']\
# /tmp/ipykernel_30571/949018458.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['tune_results_history']\
# /tmp/ipykernel_30571/949018458.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['tune_results_history']\
# /tmp/ipykernel_30571/949018458.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   history = compas[compas['fitness_rule'] == fitness_rule][compas['method'] == 'Fair Transition Loss']['tune_results_history']\
