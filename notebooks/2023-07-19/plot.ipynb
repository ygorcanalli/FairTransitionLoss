585083961487, 0.6222857236862183, 0.6248041987419128, 0.6246506571769714, 0.6217942833900452, 0.62200927734375, 0.6210571527481079, 0.6200436353683472, 0.6200128793716431, 0.6182007789611816, 0.6182929277420044, 0.6173715591430664, 0.6186307668685913], 'val_loss': [0.4649544925140109, 0.46191454704721174, 0.4609791098410679, 0.45796724547662415, 0.45610280061267305, 0.4561987082196442, 0.4556668161225622, 0.4557129080418133, 0.4550243016268549, 0.4550103545847883, 0.4556778461778935, 0.4565358052041532, 0.45652479081604613, 0.456400108156595, 0.45622844924051636, 0.45696896350864813, 0.4576851391805477, 0.45994987942158944, 0.4592093723198536, 0.4598848647080185], 'val_accuracy': [0.6404090523719788, 0.6409618854522705, 0.621061384677887, 0.6379215121269226, 0.6241016983985901, 0.6376451253890991, 0.6343283653259277, 0.626589298248291, 0.6354339122772217, 0.6290768384933472, 0.6310116052627563, 0.6243780851364136, 0.6246545314788818, 0.6310116052627563, 0.6260364651679993, 0.6238253116607666, 0.6238253116607666, 0.627694845199585, 0.6268656849861145, 0.6221669316291809]}]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json

# %%
for data in  tf_history:
    fig, ax = plt.subplots(figsize=(16, 9), dpi = 300)
    sns.lineplot(data, ax=ax)

# %%
compas = pd.read_csv('compas_result.csv')

# %%
compas.replace({'ftl_mlp_initializer': 'Fair Transition Loss', 'adversarial_debiasing_initializer': 'Adversarial Debiasing', 'gerry_fair_classifier_initializer': 'Gerry Fair Classifier', 'prejudice_remover_initializer': 'Prejudice Remover', 'simple_mlp_initializer': 'Standard MLP (baseline)'}, inplace=True)

# %%
cols = ['method', 'fitness_rule', 'fitness', 'ACC', 'MCC', 'f1_score', 'avg_odds_diff', 'stat_par_diff', 'eq_opp_diff']

# %%
compas[cols].sort_values(by=['fitness_rule','fitness'], ascending=False)
# Out:
#                      method     fitness_rule   fitness       ACC       MCC  \
# 1      Fair Transition Loss       mcc_parity  0.245965  0.616694  0.257631
# 2     Adversarial Debiasing       mcc_parity  0.170786  0.663695  0.323702
# 4     Gerry Fair Classifier       mcc_parity  0.027962  0.506483  0.104729
# 3         Prejudice Remover       mcc_parity -0.370206  0.343598 -0.311927
# 0   Standard MLP (baseline)       mcc_parity -0.517119  0.331442 -0.326608
# 11     Fair Transition Loss  mcc_opportunity  0.176096  0.664506  0.322694
# 12    Adversarial Debiasing  mcc_opportunity  0.089269  0.670178  0.333187
# 14    Gerry Fair Classifier  mcc_opportunity  0.007703  0.483793  0.041930
# 13        Prejudice Remover  mcc_opportunity -0.323781  0.369530 -0.252897
# 10  Standard MLP (baseline)  mcc_opportunity -0.493394  0.325770 -0.335568
# 7     Adversarial Debiasing         mcc_odds  0.259983  0.668558  0.333329
# ...

# %%
compas[compas['fitness_rule'] == 'mcc_odds'][['method', 'fitness', 'MCC', 'avg_odds_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                     method   fitness       MCC  avg_odds_diff
# 7    Adversarial Debiasing  0.259983  0.333329       0.073346
# 6     Fair Transition Loss  0.183877  0.238177       0.054300
# 9    Gerry Fair Classifier  0.183487  0.307984       0.124497
# 8        Prejudice Remover -0.366029 -0.301392       0.064636
# 5  Standard MLP (baseline) -0.419855 -0.305135       0.114721

# %%
compas[compas['fitness_rule'] == 'mcc_opportunity'][['method', 'fitness', 'MCC', 'eq_opp_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                      method   fitness       MCC  eq_opp_diff
# 11     Fair Transition Loss  0.176096  0.322694     0.146597
# 12    Adversarial Debiasing  0.089269  0.333187     0.243918
# 14    Gerry Fair Classifier  0.007703  0.041930     0.034227
# 13        Prejudice Remover -0.323781 -0.252897     0.070884
# 10  Standard MLP (baseline) -0.493394 -0.335568     0.157826

# %%
compas[compas['fitness_rule'] == 'acc_opportunity'][['method', 'fitness', 'ACC', 'eq_opp_diff']].sort_values(by=['fitness'], ascending=False)
# Out:
#                      method   fitness       ACC  eq_opp_diff
# 26     Fair Transition Loss  0.627032  0.635332     0.008300
# 29    Gerry Fair Classifier  0.625455  0.662075     0.036619
# 27    Adversarial Debiasing  0.584893  0.657212     0.072319
# 28        Prejudice Remover  0.281643  0.341167     0.059524
# 25  Standard MLP (baseline)  0.183516  0.319287     0.135771

# %%
tf_history = compas[compas['fitness_rule'] == 'acc_opportunity'][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']
tf_history.iloc[0]
tf_history = {'loss': [0.6831347463662143, 0.6502595228986661, 0.6391445075936564, 0.6349767165346225, 0.6324331233914464, 0.6302116061954193, 0.6268368651131623, 0.625545410214042, 0.6229172168510619, 0.6217826497826014, 0.6202210615174839, 0.6188731919029968, 0.6187339219646321, 0.6164409000880547, 0.6168509675833953, 0.6143173971646647, 0.6143944629491732, 0.6133957178266662, 0.610515843616141, 0.6084972340987056], 'val_loss': [0.6684274186006924, 0.669084594075979, 0.6671928403831204, 0.6714500463925875, 0.6676799954190428, 0.6741804289914336, 0.6741549560898229, 0.668721765400427, 0.6712413883884909, 0.6734554567317731, 0.6700116193246263, 0.6732353799738865, 0.6732463081356003, 0.6745712240697884, 0.6737823693858467, 0.669662402467689, 0.6771488817114579, 0.677528650413158, 0.6779220263485001, 0.6748567160807157]}
# Out:
# /tmp/ipykernel_368837/1546210966.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tf_history = compas[compas['fitness_rule'] == 'acc_opportunity'][compas['method'] == 'Fair Transition Loss']['best_solution_tf_history']

# %%
fig, ax = plt.subplots(figsize=(16, 9), dpi = 300)
sns.lineplot(tf_history, ax=ax)
# Out:
# <AxesSubplot:>
